# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from plots import sns_plot, line_plot

# %%
fig_name = "results/bo-evo_encoder.png"
type_name = "gb1"
spec_name = "with_imputed"
explorer = "bo_evo"
model = "gpr"
names_and_dirs = {
    "Onehot": f"runs_{type_name}/{spec_name}/{explorer}/onehot/{model}/enc_onehot",
    "Georgiev": f"runs_{type_name}/{spec_name}/{explorer}/georgiev/{model}/enc_georgiev",
    "UniRep": f"runs_{type_name}/{spec_name}/{explorer}/unirep/{model}/enc_unirep",
    "TAPE-BERT": f"runs_{type_name}/{spec_name}/{explorer}/transformer/{model}/enc_transformer",
    "Prot-BERT": f"runs_{type_name}/{spec_name}/{explorer}/prot_bert_bfd/{model}/enc_prot_bert_bfd",
    "Prot-T5": f"runs_{type_name}/{spec_name}/{explorer}/prot_t5_xl_uniref50/{model}/enc_prot_t5_xl_uniref50",
    "ESM-1b": f"runs_{type_name}/{spec_name}/{explorer}/esm-1b/{model}/enc_esm-1b",
}
sns_plot(names_and_dirs, save_name=fig_name, x_is_round=True)

# %%
fig_name = "results/explorer.png"
type_name = "gb1"
spec_name = "with_imputed"
encoding = "onehot"
model = "gpr"
names_and_dirs = {
    "Random": f"runs_{type_name}/{spec_name}/random/{encoding}/{model}/expl_random",
    "AdaLead": f"runs_{type_name}/{spec_name}/adalead/{encoding}/{model}/expl_adalead",
    "BO-EVO": f"runs_{type_name}/{spec_name}/bo_evo/{encoding}/{model}/expl_bo_evo",
    "BO-ENU": f"runs_{type_name}/{spec_name}/bo_enu/{encoding}/{model}/expl_bo_enu",
}
sns_plot(names_and_dirs, save_name=fig_name, x_is_round=True)
